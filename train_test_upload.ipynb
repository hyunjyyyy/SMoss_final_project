# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunjyyyy/SMoss_final_project/blob/main/train_test_upload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/hyunjyyyy/SMoss_final_project.git
# Out:
# Cloning into 'SMoss_final_project'...
# remote: Enumerating objects: 422, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 422 (delta 16), reused 72 (delta 14), pack-reused 348
# Receiving objects: 100% (422/422), 177.03 MiB | 21.99 MiB/s, done.
# Resolving deltas: 100% (158/158), done.
# Updating files: 100% (297/297), done.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import Dataset, DataLoader, random_split, WeightedRandomSampler
from PIL import Image
import pandas as pd
import os
import json
import matplotlib.pyplot as plt
from torch.optim.lr_scheduler import ReduceLROnPlateau

# GPU 사용 가능 확인 및 장치 설정
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 데이터 프레임 생성 (이미지와 라벨 정보 포함)
image_root = '/content/SMoss_final_project/Sample/01.원천데이터/'
label_root = '/content/SMoss_final_project/Sample/02.라벨링데이터/'

data = []

for dirpath, _, filenames in os.walk(image_root):
    for filename in filenames:
        if filename.endswith('.jpg'):
            image_path = os.path.join(dirpath, filename)
            label_path = os.path.join(label_root, os.path.relpath(dirpath, image_root), filename.replace('.jpg', '.json'))

            with open(label_path, 'r') as f:
                label_data = json.load(f)
                image_info = label_data['IMAGE_INFO']
                annotation_info = label_data['ANNOTATION_INFO'][0]
                label = annotation_info['CLASS']

            data.append({
                'image_path': image_path,
                'label': label
            })

df = pd.DataFrame(data)

# 클래스 인덱스를 문자열 라벨에서 정수로 변환하기 위해 고유 라벨 목록 생성
label_to_index = {label: idx for idx, label in enumerate(df['label'].unique())}
df['label'] = df['label'].map(label_to_index)

# 클래스별 데이터 수 계산
class_counts = df['label'].value_counts().to_dict()

# 가장 많이 있는 클래스의 데이터 수 찾기
max_count = max(class_counts.values())

# 데이터 증강 비율 계산
class_weights = {label: max_count / count for label, count in class_counts.items()}

# 데이터 증강을 위한 전처리 함수 정의
train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),  # 추가: 수직 뒤집기
    transforms.RandomRotation(20),  # 강화된 회전
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.3),  # 강화된 색상 조정
    transforms.RandomGrayscale(p=0.1),  # 일부 이미지를 무작위로 흑백으로 변환
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),  # ResNet-50 입력 크기에 맞춤
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # ImageNet 데이터셋의 평균과 표준편차 사용
])

# 사용자 정의 데이터셋 클래스 정의
class CustomDataset(Dataset):
    def __init__(self, dataframe, transform=None):
        self.dataframe = dataframe
        self.transform = transform
        self.weights = self.calculate_weights()

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        img_name = self.dataframe.iloc[idx, 0]
        image = Image.open(img_name).convert('RGB')
        label = self.dataframe.iloc[idx, 1]

        if self.transform:
            image = self.transform(image)

        return image, torch.tensor(label)  # label을 텐서로 변환하여 반환

    def calculate_weights(self):
        weights = self.dataframe['label'].map(class_weights).values
        return weights

# 데이터셋 생성
dataset = CustomDataset(df, transform=train_transform)

# 데이터셋을 학습과 검증으로 분리
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# WeightedRandomSampler를 사용하여 클래스 비율에 맞게 샘플링
train_sampler = WeightedRandomSampler(weights=dataset.calculate_weights()[:train_size], num_samples=train_size, replacement=True)

# DataLoader 생성
batch_size = 32  # 배치 크기 변경
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# 모델 정의 함수 (densenet 모델 추가)
def get_model(model_name, num_classes):
    if model_name == 'resnet18':
        model = models.resnet18(pretrained=True)
        num_ftrs = model.fc.in_features
        model.fc = nn.Linear(num_ftrs, num_classes)
    elif model_name == 'resnet50':
        model = models.resnet50(pretrained=True)
        num_ftrs = model.fc.in_features
        model.fc = nn.Linear(num_ftrs, num_classes)
    elif model_name == 'resnet101':
        model = models.resnet101(pretrained=True)
        num_ftrs = model.fc.in_features
        model.fc = nn.Linear(num_ftrs, num_classes)
    elif model_name == 'vgg16':
        model = models.vgg16(pretrained=True)
        num_ftrs = model.classifier[6].in_features
        model.classifier[6] = nn.Linear(num_ftrs, num_classes)
    elif model_name == 'densenet121':
        model = models.densenet121(pretrained=True)
        num_ftrs = model.classifier.in_features
        model.classifier = nn.Linear(num_ftrs, num_classes)
    else:
        raise ValueError(f'Unknown model name {model_name}')

    return model

# 손실 함수 및 최적화 기법 정의
def get_optimizer_scheduler(model):
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.0001, weight_decay=1e-4)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3, verbose=True)
    return criterion, optimizer, scheduler

# 학습 함수 정의 (학습 및 검증 손실/정확도 기록)
def train_model(model, train_dataloader, val_dataloader, criterion, optimizer, scheduler, num_epochs=50, patience=5):
    train_loss_history = []
    val_loss_history = []
    train_acc_history = []
    val_acc_history = []

    best_val_loss = float('inf')
    epochs_no_improve = 0
    best_model_wts = None

    for epoch in range(num_epochs):
        print(f'에폭 {epoch+1}/{num_epochs}')
        print('-' * 10)

        # 학습 단계
        model.train()
        running_loss = 0.0
        correct_predictions = 0
        for inputs, labels in train_dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            correct_predictions += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(train_dataloader.dataset)
        epoch_acc = correct_predictions.double() / len(train_dataloader.dataset)

        train_loss_history.append(epoch_loss)
        train_acc_history.append(epoch_acc.item())

        print(f"학습 손실: {epoch_loss:.4f} 정확도: {epoch_acc:.4f}")

        # 검증 단계
        model.eval()
        running_loss = 0.0
        correct_predictions = 0
        with torch.no_grad():
            for inputs, labels in val_dataloader:
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)

                running_loss += loss.item() * inputs.size(0)
                correct_predictions += torch.sum(preds == labels.data)

        epoch_loss = running_loss / len(val_dataloader.dataset)
        epoch_acc = correct_predictions.double() / len(val_dataloader.dataset)

        val_loss_history.append(epoch_loss)
        val_acc_history.append(epoch_acc.item())

        print(f"검증 손실: {epoch_loss:.4f} 정확도: {epoch_acc:.4f}")

        # ReduceLROnPlateau 스케줄러 step 호출
        scheduler.step(epoch_loss)

        # 조기 종료 확인 및 최적 모델 저장
        if epoch_loss < best_val_loss:
            best_val_loss = epoch_loss
            epochs_no_improve = 0
            best_model_wts = model.state_dict()
            save_model(model, f"best_{model_name}")  # 최적 모델 저장
        else:
            epochs_no_improve += 1

        if epochs_no_improve == patience:
            print(f'조기 종료! 검증 손실이 {patience} 에폭 동안 개선되지 않아 에폭 {epoch+1} 에서 학습 중지.')
            break

    # 최적 모델 상태로 복원
    if best_model_wts is not None:
        model.load_state_dict(best_model_wts)

    # 학습 및 검증 손실/정확도 시각화
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    plt.plot(train_loss_history, label='학습 손실')
    plt.plot(val_loss_history, label='검증 손실')
    plt.xlabel('에폭')
    plt.ylabel('손실')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(train_acc_history, label='학습 정확도')
    plt.plot(val_acc_history, label='검증 정확도')
    plt.xlabel('에폭')
    plt.ylabel('정확도')
    plt.legend()
    plt.tight_layout()
    plt.show()

    return model

# 모델 저장 함수
def save_model(model, model_name, save_dir='./saved_models'):
    os.makedirs(save_dir, exist_ok=True)
    save_path = os.path.join(save_dir, f'{model_name}.pth')
    torch.save(model.state_dict(), save_path)
    print(f'{model_name} 저장 완료: {save_path}')

# 모델 로드 함수
def load_model(model_name, model_class, num_classes, save_dir='./saved_models'):
    model = get_model(model_class, num_classes).to(device)
    save_path = os.path.join(save_dir, f'{model_name}.pth')
    model.load_state_dict(torch.load(save_path, map_location=device))
    print(f'{model_name} 로드 완료: {save_path}')
    return model

# 모델 이름과 클래스 수 설정
model_names = ['resnet18', 'resnet50', 'densenet121']  # 여기에 densenet 모델 추가 가능
num_classes = len(label_to_index)

# 모델 학습 및 저장
trained_models = {}
for model_name in model_names:
    print(f'현재 학습 중인 모델: {model_name}')
    model = get_model(model_name, num_classes).to(device)
    criterion, optimizer, scheduler = get_optimizer_scheduler(model)
    trained_model = train_model(model, train_dataloader, val_dataloader, criterion, optimizer, scheduler)
    trained_models[model_name] = trained_model

# 모델 로드 예시
loaded_models = {}
for model_name in model_names:
    loaded_model = load_model(f"best_{model_name}", model_name, num_classes)
    loaded_models[model_name] = loaded_model

# 앙상블 예측 생성
def ensemble_predictions(models, dataloader):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    predictions = []

    num_classes = len(label_to_index)  # 클래스 수를 데이터셋에 맞게 설정

    for inputs, _ in dataloader:
        inputs = inputs.to(device)

        # 각 모델에 대해 softmax 적용 후 평균 계산
        avg_outputs = torch.zeros(inputs.size(0), num_classes).to(device)
        for model in models:
            model.eval()
            with torch.no_grad():
                outputs = torch.softmax(model(inputs), dim=1)
                avg_outputs += outputs / len(models)  # 모델 수에 맞게 평균을 더함

        _, preds = torch.max(avg_outputs, 1)
        predictions.extend(preds.cpu().numpy())

    return predictions

# 검증 데이터셋에 대한 각 모델의 예측 생성
ensemble_models = [loaded_models[model_name] for model_name in model_names]
val_predictions = ensemble_predictions(ensemble_models, val_dataloader)

# 예측 평가
val_labels = [label.item() for _, label in val_dataset]
accuracy = sum(1 for x, y in zip(val_predictions, val_labels) if x == y) / len(val_labels)
print(f'앙상블 검증 정확도: {accuracy:.4f}')

# 이미지 분류 함수
def classify_image(image_path, models):
    # 이미지 열기
    image = Image.open(image_path).convert('RGB')

    # 이미지 전처리
    image = test_transform(image).unsqueeze(0)  # 배치 차원을 추가

    # GPU로 이미지 옮기기
    image = image.to(device)

    # 모델로 예측
    avg_outputs = torch.zeros(1, num_classes).to(device)
    with torch.no_grad():
        for model in models:
            model.eval()
            outputs = torch.softmax(model(image), dim=1)
            avg_outputs += outputs / len(models)  # 모델 수에 맞게 평균을 더함

    _, preds = torch.max(avg_outputs, 1)
    predicted_label = list(label_to_index.keys())[preds.item()]  # 인덱스를 실제 라벨로 변환
    return predicted_label

# 테스트할 이미지 경로
test_image_path = '/content/styrofoam.jpg'

# 이미지 분류
predicted_label = classify_image(test_image_path, ensemble_models)
print(f'The predicted label for the image is: {predicted_label}')
# Out:
# 현재 학습 중인 모델: resnet18
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# 에폭 1/50
# ----------
# 학습 손실: 2.1782 정확도: 0.2159
# 검증 손실: 2.1581 정확도: 0.2174
# best_resnet18 저장 완료: ./saved_models/best_resnet18.pth
# 에폭 2/50
# ----------
# 학습 손실: 1.9950 정확도: 0.3182
# 검증 손실: 2.2111 정확도: 0.2174
# 에폭 3/50
# ----------
# 학습 손실: 1.7221 정확도: 0.4091
# 검증 손실: 1.9574 정확도: 0.2174
# best_resnet18 저장 완료: ./saved_models/best_resnet18.pth
# 에폭 4/50
# ----------
# 학습 손실: 1.6790 정확도: 0.3636
# 검증 손실: 1.8806 정확도: 0.3478
# best_resnet18 저장 완료: ./saved_models/best_resnet18.pth
# 에폭 5/50
# ----------
# 학습 손실: 1.4428 정확도: 0.5455
# 검증 손실: 1.7269 정확도: 0.3478
# best_resnet18 저장 완료: ./saved_models/best_resnet18.pth
# 에폭 6/50
# ----------
# 학습 손실: 1.2444 정확도: 0.5909
# 검증 손실: 1.7837 정확도: 0.3913
# 에폭 7/50
# ----------
# 학습 손실: 1.1514 정확도: 0.6136
# 검증 손실: 1.9240 정확도: 0.3478
# 에폭 8/50
# ----------
# 학습 손실: 0.9977 정확도: 0.7159
# 검증 손실: 1.9628 정확도: 0.3043
# 에폭 9/50
# ----------
# 학습 손실: 0.7447 정확도: 0.8182
# 검증 손실: 1.7471 정확도: 0.4348
# 에폭 10/50
# ----------
# 학습 손실: 0.9211 정확도: 0.7727
# 검증 손실: 1.6806 정확도: 0.3913
# best_resnet18 저장 완료: ./saved_models/best_resnet18.pth
# 에폭 11/50
# ----------
# 학습 손실: 0.8831 정확도: 0.7273
# 검증 손실: 1.6104 정확도: 0.4348
# best_resnet18 저장 완료: ./saved_models/best_resnet18.pth
# 에폭 12/50
# ----------
# 학습 손실: 0.8649 정확도: 0.7159
# 검증 손실: 1.8888 정확도: 0.2609
# 에폭 13/50
# ----------
# 학습 손실: 0.8379 정확도: 0.7614
# 검증 손실: 1.8518 정확도: 0.4783
# 에폭 14/50
# ----------
# 학습 손실: 0.7193 정확도: 0.7955
# 검증 손실: 1.7870 정확도: 0.3913
# 에폭 15/50
# ----------
# 학습 손실: 0.7565 정확도: 0.8068
# 검증 손실: 1.6872 정확도: 0.4783
# 에폭 16/50
# ----------
# 학습 손실: 0.7923 정확도: 0.7614
# 검증 손실: 1.7447 정확도: 0.2609
# 조기 종료! 검증 손실이 5 에폭 동안 개선되지 않아 에폭 16 에서 학습 중지.
# <ipython-input-18-aee21573cc6a>:225: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from current font.
#   plt.tight_layout()
# <ipython-input-18-aee21573cc6a>:225: UserWarning: Glyph 54253 (\N{HANGUL SYLLABLE POG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-18-aee21573cc6a>:225: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from current font.
#   plt.tight_layout()
# <ipython-input-18-aee21573cc6a>:225: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   plt.tight_layout()
# <ipython-input-18-aee21573cc6a>:225: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-18-aee21573cc6a>:225: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from current font.
#   plt.tight_layout()
# <ipython-input-18-aee21573cc6a>:225: UserWarning: Glyph 44160 (\N{HANGUL SYLLABLE GEOM}) missing from current font.
#   plt.tight_layout()
# <ipython-input-18-aee21573cc6a>:225: UserWarning: Glyph 51613 (\N{HANGUL SYLLABLE JEUNG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-18-aee21573cc6a>:225: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-18-aee21573cc6a>:225: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from current font.
#   plt.tight_layout()
# <ipython-input-18-aee21573cc6a>:225: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   plt.tight_layout()
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54253 (\N{HANGUL SYLLABLE POG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49552 (\N{HANGUL SYLLABLE SON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54617 (\N{HANGUL SYLLABLE HAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49845 (\N{HANGUL SYLLABLE SEUB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44160 (\N{HANGUL SYLLABLE GEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51613 (\N{HANGUL SYLLABLE JEUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 현재 학습 중인 모델: resnet50
# 에폭 1/50
# ----------
# 학습 손실: 2.1980 정확도: 0.1705
# 검증 손실: 2.1706 정확도: 0.2174
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 2/50
# ----------
# 학습 손실: 1.9087 정확도: 0.4773
# 검증 손실: 1.9728 정확도: 0.4348
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 3/50
# ----------
# 학습 손실: 1.5921 정확도: 0.6250
# 검증 손실: 1.8048 정확도: 0.5217
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 4/50
# ----------
# 학습 손실: 1.3618 정확도: 0.5682
# 검증 손실: 1.7321 정확도: 0.5217
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 5/50
# ----------
# 학습 손실: 1.1900 정확도: 0.6705
# 검증 손실: 1.8068 정확도: 0.3913
# 에폭 6/50
# ----------
# 학습 손실: 0.9879 정확도: 0.6477
# 검증 손실: 1.7306 정확도: 0.3913
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 7/50
# ----------
# 학습 손실: 0.9656 정확도: 0.6364
# 검증 손실: 1.8625 정확도: 0.4348
# 에폭 8/50
# ----------
# 학습 손실: 0.8953 정확도: 0.7273
# 검증 손실: 1.6463 정확도: 0.5217
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 9/50
# ----------
# 학습 손실: 0.9115 정확도: 0.6818
# 검증 손실: 1.9803 정확도: 0.4348
# 에폭 10/50
# ----------
# 학습 손실: 0.5497 정확도: 0.8409
# 검증 손실: 2.1611 정확도: 0.3478
# 에폭 11/50
# ----------
# 학습 손실: 0.5819 정확도: 0.8295
# 검증 손실: 2.1448 정확도: 0.3913
# 에폭 12/50
# ----------
# 학습 손실: 0.7079 정확도: 0.7841
# 검증 손실: 1.6724 정확도: 0.4783
# 에폭 13/50
# ----------
# 학습 손실: 0.7539 정확도: 0.7614
# 검증 손실: 1.5641 정확도: 0.4348
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 14/50
# ----------
# 학습 손실: 0.5834 정확도: 0.8068
# 검증 손실: 1.7007 정확도: 0.4348
# 에폭 15/50
# ----------
# 학습 손실: 0.5303 정확도: 0.8409
# 검증 손실: 1.8046 정확도: 0.5217
# 에폭 16/50
# ----------
# 학습 손실: 0.4620 정확도: 0.8636
# 검증 손실: 1.4716 정확도: 0.5652
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 17/50
# ----------
# 학습 손실: 0.5422 정확도: 0.8295
# 검증 손실: 1.5525 정확도: 0.5217
# 에폭 18/50
# ----------
# 학습 손실: 0.5613 정확도: 0.8409
# 검증 손실: 1.5851 정확도: 0.5217
# 에폭 19/50
# ----------
# 학습 손실: 0.4509 정확도: 0.8636
# 검증 손실: 1.5012 정확도: 0.5652
# 에폭 20/50
# ----------
# 학습 손실: 0.5247 정확도: 0.8750
# 검증 손실: 1.3862 정확도: 0.5652
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 21/50
# ----------
# 학습 손실: 0.4633 정확도: 0.8864
# 검증 손실: 1.4810 정확도: 0.4783
# 에폭 22/50
# ----------
# 학습 손실: 0.5486 정확도: 0.7955
# 검증 손실: 1.6719 정확도: 0.3913
# 에폭 23/50
# ----------
# 학습 손실: 0.4972 정확도: 0.8977
# 검증 손실: 1.3768 정확도: 0.5652
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 24/50
# ----------
# 학습 손실: 0.3501 정확도: 0.9205
# 검증 손실: 1.6504 정확도: 0.3913
# 에폭 25/50
# ----------
# 학습 손실: 0.4383 정확도: 0.9205
# 검증 손실: 1.4977 정확도: 0.3913
# 에폭 26/50
# ----------
# 학습 손실: 0.4981 정확도: 0.8636
# 검증 손실: 1.3721 정확도: 0.3913
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 27/50
# ----------
# 학습 손실: 0.5426 정확도: 0.8409
# 검증 손실: 1.4981 정확도: 0.4348
# 에폭 28/50
# ----------
# 학습 손실: 0.3878 정확도: 0.8977
# 검증 손실: 1.4296 정확도: 0.4783
# 에폭 29/50
# ----------
# 학습 손실: 0.4575 정확도: 0.8977
# 검증 손실: 1.3594 정확도: 0.5652
# best_resnet50 저장 완료: ./saved_models/best_resnet50.pth
# 에폭 30/50
# ----------
# 학습 손실: 0.3792 정확도: 0.8864
# 검증 손실: 1.5094 정확도: 0.4348
# 에폭 31/50
# ----------
# 학습 손실: 0.5597 정확도: 0.8068
# 검증 손실: 1.4089 정확도: 0.5217
# 에폭 32/50
# ----------
# 학습 손실: 0.3527 정확도: 0.9432
# 검증 손실: 1.4896 정확도: 0.3913
# 에폭 33/50
# ----------
# 학습 손실: 0.4750 정확도: 0.8523
# 검증 손실: 1.5508 정확도: 0.4783
# 에폭 34/50
# ----------
# 학습 손실: 0.4830 정확도: 0.8636
# 검증 손실: 1.7160 정확도: 0.3043
# 조기 종료! 검증 손실이 5 에폭 동안 개선되지 않아 에폭 34 에서 학습 중지.
# 현재 학습 중인 모델: densenet121
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 에폭 1/50
# ----------
# 학습 손실: 2.1152 정확도: 0.2500
# 검증 손실: 2.1343 정확도: 0.1739
# best_densenet121 저장 완료: ./saved_models/best_densenet121.pth
# 에폭 2/50
# ----------
# 학습 손실: 1.9999 정확도: 0.2727
# 검증 손실: 2.1090 정확도: 0.1304
# best_densenet121 저장 완료: ./saved_models/best_densenet121.pth
# 에폭 3/50
# ----------
# 학습 손실: 1.7077 정확도: 0.5114
# 검증 손실: 2.1270 정확도: 0.1739
# 에폭 4/50
# ----------
# 학습 손실: 1.5937 정확도: 0.5682
# 검증 손실: 1.9367 정확도: 0.3913
# best_densenet121 저장 완료: ./saved_models/best_densenet121.pth
# 에폭 5/50
# ----------
# 학습 손실: 1.5463 정확도: 0.5341
# 검증 손실: 1.9632 정확도: 0.3913
# 에폭 6/50
# ----------
# 학습 손실: 1.4673 정확도: 0.5682
# 검증 손실: 1.9945 정확도: 0.3478
# 에폭 7/50
# ----------
# 학습 손실: 1.2937 정확도: 0.5795
# 검증 손실: 1.8369 정확도: 0.4348
# best_densenet121 저장 완료: ./saved_models/best_densenet121.pth
# 에폭 8/50
# ----------
# 학습 손실: 1.3630 정확도: 0.5114
# 검증 손실: 1.9292 정확도: 0.3478
# 에폭 9/50
# ----------
# 학습 손실: 0.9639 정확도: 0.8182
# 검증 손실: 1.8505 정확도: 0.3913
# 에폭 10/50
# ----------
# 학습 손실: 1.1398 정확도: 0.6477
# 검증 손실: 1.7089 정확도: 0.5652
# best_densenet121 저장 완료: ./saved_models/best_densenet121.pth
# 에폭 11/50
# ----------
# 학습 손실: 1.1399 정확도: 0.6818
# 검증 손실: 1.8674 정확도: 0.3913
# 에폭 12/50
# ----------
# 학습 손실: 0.9003 정확도: 0.8409
# 검증 손실: 1.6711 정확도: 0.4348
# best_densenet121 저장 완료: ./saved_models/best_densenet121.pth
# 에폭 13/50
# ----------
# 학습 손실: 0.8702 정확도: 0.8068
# 검증 손실: 1.6881 정확도: 0.5217
# 에폭 14/50
# ----------
# 학습 손실: 0.8144 정확도: 0.7614
# 검증 손실: 1.5929 정확도: 0.4783
# best_densenet121 저장 완료: ./saved_models/best_densenet121.pth
# 에폭 15/50
# ----------
# 학습 손실: 0.8409 정확도: 0.7955
# 검증 손실: 1.7815 정확도: 0.3913
# 에폭 16/50
# ----------
# 학습 손실: 0.7186 정확도: 0.8523
# 검증 손실: 1.5048 정확도: 0.4783
# best_densenet121 저장 완료: ./saved_models/best_densenet121.pth
# 에폭 17/50
# ----------
# 학습 손실: 0.5094 정확도: 0.9205
# 검증 손실: 1.2917 정확도: 0.5217
# best_densenet121 저장 완료: ./saved_models/best_densenet121.pth
# 에폭 18/50
# ----------
# 학습 손실: 0.6739 정확도: 0.8523
# 검증 손실: 1.4856 정확도: 0.5652
# 에폭 19/50
# ----------
# 학습 손실: 0.5613 정확도: 0.8750
# 검증 손실: 1.4720 정확도: 0.5217
# 에폭 20/50
# ----------
# 학습 손실: 0.7323 정확도: 0.7500
# 검증 손실: 1.5800 정확도: 0.5652
# 에폭 21/50
# ----------
# 학습 손실: 0.5494 정확도: 0.8523
# 검증 손실: 1.5057 정확도: 0.4783
# 에폭 22/50
# ----------
# 학습 손실: 0.4921 정확도: 0.8977
# 검증 손실: 1.5995 정확도: 0.4783
# 조기 종료! 검증 손실이 5 에폭 동안 개선되지 않아 에폭 22 에서 학습 중지.
# best_resnet18 로드 완료: ./saved_models/best_resnet18.pth
# best_resnet50 로드 완료: ./saved_models/best_resnet50.pth
# best_densenet121 로드 완료: ./saved_models/best_densenet121.pth
# 앙상블 검증 정확도: 0.4783
# The predicted label for the image is: 플라스틱

# %% [markdown]
# **아래는 테스트용 이미지 분류하는 코드입니다.**

# %%
# 이미지 분류 함수
def classify_image(image_path, models):
    # 이미지 열기
    image = Image.open(image_path).convert('RGB')

    # 이미지 전처리
    image = test_transform(image).unsqueeze(0)  # 배치 차원을 추가

    # GPU로 이미지 옮기기
    image = image.to(device)

    # 모델로 예측
    avg_outputs = torch.zeros(1, num_classes).to(device)
    with torch.no_grad():
        for model in models:
            model.eval()
            outputs = torch.softmax(model(image), dim=1)
            avg_outputs += outputs / len(models)  # 모델 수에 맞게 평균을 더함

    _, preds = torch.max(avg_outputs, 1)
    predicted_label = list(label_to_index.keys())[preds.item()]  # 인덱스를 실제 라벨로 변환
    return predicted_label

# 테스트할 이미지 경로
test_image_path = '/content/styrofoam.jpg'

# 이미지 분류
predicted_label = classify_image(test_image_path, ensemble_models)
print(f'The predicted label for the image is: {predicted_label}')
# Out:
# The predicted label for the image is: 플라스틱

# %% [markdown]
# 밑은 모델학습 검증용 상위 3개 나타내는 코드

# %%
# 이미지 분류 함수 (상위 3개의 클래스와 확률 반환)
def classify_image(image_path, models):
    # 이미지 열기
    image = Image.open(image_path).convert('RGB')

    # 이미지 전처리
    image = test_transform(image).unsqueeze(0)  # 배치 차원을 추가

    # GPU로 이미지 옮기기
    image = image.to(device)

    # 모델로 예측
    avg_outputs = torch.zeros(1, num_classes).to(device)
    with torch.no_grad():
        for model in models:
            model.eval()
            outputs = torch.softmax(model(image), dim=1)
            avg_outputs += outputs / len(models)  # 모델 수에 맞게 평균을 더함

    topk_probs, topk_indices = torch.topk(avg_outputs, 3, dim=1)
    topk_probs = topk_probs.cpu().numpy().flatten()
    topk_indices = topk_indices.cpu().numpy().flatten()

    topk_labels = [list(label_to_index.keys())[index] for index in topk_indices]
    return list(zip(topk_labels, topk_probs))

# 테스트할 이미지 경로
test_image_path = '/content/paperbox.png'

# 이미지 분류
top3_predictions = classify_image(test_image_path, ensemble_models)
print(f'Top 3 predicted labels and probabilities for the image: {top3_predictions}')
# Out:
# Top 3 predicted labels and probabilities for the image: [('플라스틱', 0.29253823), ('종이', 0.22531009), ('금속캔', 0.13495822)]
